# %%
# Source: https://towardsdatascience.com/linear-regression-using-gradient-descent-97a6c8700931

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = np.linspace(0, 1000, 100)
delta = np.random.uniform(-50, 50, X.size)
Y = np.random.rand()*X + delta

plt.scatter(X, Y)
plt.show()

# %% [markdown]
# Normalize

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = MinMaxScaler()

X = X.reshape(-1, 1)
Y = Y.reshape(-1, 1)

X = scaler.fit_transform(X)
Y = scaler.fit_transform(Y)

plt.scatter(X, Y)
plt.show()

# %%
# Building the model
m = 0
c = 0

L = 0.5  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X
loss = 1e9

# Performing Gradient Descent
for i in range(epochs):
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    current_loss = np.mean((Y_pred - Y)**2)
    if loss - current_loss < 1e-6:
        print("Found @epoch = ", i)
        break
    else:
        loss = current_loss
    
print (m, c)
# Out:
# Found @epoch =  62
# [0.83999482] [0.10417254]

# %%
# Making predictions
Y_pred = m*X + c

plt.scatter(X, Y) 
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')  # regression line
plt.show()
